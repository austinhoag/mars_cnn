# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %% [markdown]
# ## Check that tensorflow can use GPU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
gpus
# Out:
# []

# %%
tf.test.gpu_device_name()
# Out:
# ''

# %%
cpus = tf.config.experimental.list_physical_devices('CPU')
cpus
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# ## Single hidden layer NN

# %%
model = Sequential([
    Dense(5, input_shape=(3,),activation='relu'), # implicity creates the input layer
    Dense(2, activation='softmax'),
])

# %%
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Run inference on new data with loaded model
# Note that data augmentation and dropout are inactive at inference time.

# %%
test_fld = '/home/ahoag/ML/mars/test_cnn'
image_size = (180, 180)

# %%
def inference(filename):
    """
    ---PURPOSE---
    
    """
    # Find an image that was not used in training or validation set that I know the answer to. 
    full_filename = os.path.join(test_fld,filename)
    pil_im = Image.open(full_filename)
    img = keras.preprocessing.image.load_img(
        full_filename, target_size=image_size
    )

    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    plt.figure(figsize=(4, 4))
    ax = plt.subplot(1,1,1)
    _=plt.imshow(pil_im)
    plt.axis("off")
    predictions = reconstructed_model.predict(img_array)
    score = predictions[0]
    print(
        "P = %.2f that there are craters"
        % (score)
    )
    return

# %%
# Find an image that was not used in training or validation set that I know the answer to. 
filename = "PSP_010420_2505_x200-400_y400-600.jpg"
inference(filename)
# Out:
# P = 0.01 that there are craters

# %%
# Find an image that was not used in training or validation set that I know the answer to. 
filename = "ESP_028825_2070_x200-400_y0-200.jpg"
inference(filename)
# Out:
# P = 0.96 that there are craters

# %% [markdown]
# These are giving me the same results as when my model was freshly made so the loading worked!
